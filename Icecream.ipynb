# %% [markdown]
# import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
icecream = pd.read_csv(r"C:\Users\User\Desktop\Study Guide\ML Projects\Polynomial Regression\Icecream_Polynomial_Regression\Ice_cream selling data.csv")

# %%
icecream.head()
# Out:
#    Temperature (°C)  Ice Cream Sales (units)
# 0         -4.662263                41.842986
# 1         -4.316559                34.661120
# 2         -4.213985                39.383001
# 3         -3.949661                37.539845
# 4         -3.578554                32.284531

# %%
icecream.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Temperature (°C)         49 non-null     float64
#  1   Ice Cream Sales (units)  49 non-null     float64
# dtypes: float64(2)
# memory usage: 916.0 bytes

# %%
X= icecream.iloc[ : , 0:-1].values
y= icecream.iloc[ : , -1].values

# %%
plt.scatter(X,y, color = 'red')
plt.title("Icecream Sales Data")
plt.xlabel("Temperature")
plt.ylabel("Revenue")
# Out:
# Text(0, 0.5, 'Revenue')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size =0.2 ,random_state= 0)

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
linear_reg= LinearRegression()
poly_reg= PolynomialFeatures(degree=4)
X_train_poly=poly_reg.fit_transform(X_train)
X_test_poly = poly_reg.transform(X_test)
poly_reg.fit(X_train_poly,y_train)
linear_reg.fit(X_train_poly,y_train)
# Out:
# LinearRegression()

# %%
y_pred=linear_reg.predict(X_test_poly)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test,y_pred)
# Out:
# np.float64(2.8319609567403434)

# %%
y_pred_train=linear_reg.predict(X_train_poly)
mean_absolute_error(y_train,y_pred_train)
# Out:
# np.float64(2.252814278048069)
